# %% [markdown]
# * Startar apenas com VSCode aberto e maximizado.
# * Tríade de informações para análise prévia: NF + FOTOS + CHECKLISTS
# * Storytelling Padrão: 1️⃣PLACA → 2️⃣DENTRO DO VEÍCULO → 3️⃣AVARIA

# %% [markdown]
# ## RNC (Registro de Não Conformidade)

# %%
import pandas as pd
import pyautogui
import keyboard
import webbrowser
import ctypes
import time

# %% [markdown]
# ### 🎁Confecção dos arquivos .xlsx

# %%
pyautogui.FAILSAFE = True
# CRIAR ARQUIVO .XLSX

pyautogui.click(1775,22) # Minimizar VSCode

df = pd.read_excel("Plan_RNC.xlsx", dtype={'COD-ITEM': str}) #Atualizar planilha
for index, row in df.iterrows():
    if row["CAUSA-RAIZ"] == 0:
        continue
    else:
        pyautogui.sleep(0.9)
        pyautogui.hotkey('win','r')
        pyautogui.sleep(0.5)
        keyboard.write(r'cmd /c start /max excel "C:\Users\iesus.candido\Desktop\RNC -.xlsx"')
        pyautogui.press('enter')
        pyautogui.sleep(5)

        pyautogui.hotkey('ctrl',';')
        pyautogui.press('enter')
        pyautogui.sleep(0.5)

        pyautogui.press('left')
        pyautogui.press('left')
        
        
        
        if row["UNIDADE"] == "Hortolândia":
            keyboard.write("Hortolândia")
        else:
            keyboard.write("Cuiabá")
    
        pyautogui.press('down')
        
        pyautogui.sleep(0.7)
        fornecedor = str(row['FORNECEDOR'])
        keyboard.write(fornecedor)
        pyautogui.sleep(0.5)

        pyautogui.press('enter',4)
        pyautogui.sleep(0.1)
        pyautogui.press('left')
        
        pyautogui.sleep(0.1)
        keyboard.write(str(int(row['NUMERO-NF'])))
        pyautogui.sleep(0.5)

        pyautogui.press('right')

        pyautogui.sleep(0.1)
        keyboard.write(str(row['NOME-PRODUTO']))
        pyautogui.sleep(0.5)

        pyautogui.press('right')

        pyautogui.sleep(0.1)
        keyboard.write(str(row['LOTE']))
        pyautogui.sleep(0.5)

        pyautogui.press('right')

        pyautogui.sleep(0.1)
        keyboard.write(str(int(row['QUANTIDADE'])))

        pyautogui.sleep(0.1)
        keyboard.write(str(row['UNIDADE-MED']))
        pyautogui.sleep(0.5)

        pyautogui.press('down')
        pyautogui.press('down')
        pyautogui.press('down')
        pyautogui.press('down')
        pyautogui.press('down')
        pyautogui.press('down')

        pyautogui.sleep(0.1)
        keyboard.write(str(row['DESCRICAO']))
        pyautogui.sleep(0.9)

        pyautogui.press('down')
        pyautogui.press('down')
        pyautogui.confirm("INSERÇÃO MANUAL: OUTRAS INFORMAÇÕES + FOTOS")

        # Salvando no desktop
        pyautogui.sleep(0.9)
        pyautogui.press('alt')
        pyautogui.sleep(0.7)
        
        pyautogui.press('a')
        pyautogui.sleep(0.7)

        pyautogui.press('a')
        pyautogui.sleep(0.7)

        pyautogui.press('1')
        pyautogui.sleep(1)    

        pyautogui.press('end')
        pyautogui.sleep(0.1)
        pyautogui.press('space')
        pyautogui.sleep(0.1)

        pyautogui.sleep(0.5)
        keyboard.write(str(int(row['NUM-RNC'])))
        pyautogui.sleep(0.5)
        pyautogui.press('enter')
        pyautogui.sleep(1.5)
        pyautogui.hotkey('alt','f4')

pyautogui.alert('Criação dos .xlsx concluída ✅')

# %% [markdown]
# ### 📄Preenchimento de RNC (Sharepoint)

# %%
pyautogui.FAILSAFE = True


# PREENCHIMENTOS: SHAREPOINT , PLANILHA EMAIL , CRIAR EMAILS

# Abrir planilha do Sharepoint
pyautogui.sleep(0.5)
webbrowser.open('https://nitroquimica.sharepoint.com/:x:/r/sites/NitroSharepoint-Publica/_layouts/15/Doc.aspx?sourcedoc=%7BE1076C48-A3F7-46E7-BDAD-674D0FFC6675%7D&file=Controle%20Qualidade.xlsx&action=default&mobileredirect=true')
pyautogui.sleep(12)

df = pd.read_excel("Plan_RNC.xlsx", dtype={'COD-ITEM': str}) #Atualizar planilha
for index, row in df.iterrows():
    if row["CAUSA-RAIZ"] == 0:
        continue
    else:
            pyautogui.hotkey('ctrl','home')
            pyautogui.sleep(0.7)

            pyautogui.hotkey('ctrl','down')
            pyautogui.sleep(1)

            pyautogui.hotkey('shift','space')
            pyautogui.sleep(1)

            pyautogui.hotkey('ctrl','c')
            pyautogui.sleep(1)

            pyautogui.press('down')
            pyautogui.sleep(0.5)

            pyautogui.hotkey('ctrl','v')
            pyautogui.sleep(1)

            pyautogui.press('left')
            pyautogui.sleep(0.5)
            pyautogui.press('esc')
            pyautogui.sleep(0.7)



            # Começar preenchimento das informações

            pyautogui.sleep(0.1)
            var_rnc = str(int(row['NUM-RNC']))
            keyboard.write(var_rnc)
            pyautogui.sleep(0.1)
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            pyautogui.sleep(0.1)
            keyboard.write(f'{var_rnc}-RNC')
            pyautogui.sleep(0.1)
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.sleep(0.7)
            
            pyautogui.sleep(0.1)
            pyautogui.hotkey('ctrl',';')
            pyautogui.sleep(0.7)
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.sleep(0.7)
            
            if row["UNIDADE"] == "Hortolândia":
                sigla = "HORT"
                pyautogui.sleep(0.1)
                keyboard.write("MMCM - HOR")
                pyautogui.sleep(0.3)
            if row["UNIDADE"] == "Cuiabá":
                sigla = "CBA"
                pyautogui.sleep(0.1)
                keyboard.write("MMCM - CBA")
                pyautogui.sleep(0.3)
            
            pyautogui.press('tab')
            pyautogui.sleep(0.5)
            
            keyboard.write(str(row['EMITENTE-NF']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)
            
            var_nf = str(int(row['NUMERO-NF']))
            keyboard.write(str(int(row['NUMERO-NF'])))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            keyboard.write(str(row['COD-ITEM']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)
            
            keyboard.write(str(row['NOME-PRODUTO']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            keyboard.write(str(row['LOTE']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            var_qtd = str(int(row['QUANTIDADE']))
            keyboard.write(str(int(row['QUANTIDADE'])))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            var_uni = str(row['UNIDADE-MED'])
            keyboard.write(str(row['UNIDADE-MED']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            pyautogui.press('delete')
            pyautogui.sleep(0.9)
            keyboard.write(str(row['CAUSA-RAIZ']))
            pyautogui.press('tab')
            pyautogui.sleep(0.5)

            pyautogui.press('delete')
            pyautogui.sleep(0.9)
            keyboard.write(str(row['CATEGORIA-AVARIA']))
            pyautogui.press('tab')
            pyautogui.sleep(0.5)

            pyautogui.press('delete')
            pyautogui.sleep(0.9)
            keyboard.write(str(row['RESPONSAVEL']))
            pyautogui.press('tab')
            pyautogui.sleep(0.5)

            pyautogui.press('delete')
            pyautogui.press('f2')
            pyautogui.sleep(0.7)
            keyboard.write(str(row['DESCRICAO']))
            pyautogui.press('tab')
            pyautogui.sleep(1.5)

            pyautogui.sleep(0.9)
            keyboard.write(str(row['EMBALAGEM']))
            pyautogui.sleep(0.9)
            pyautogui.press('tab')
            pyautogui.sleep(3)


pyautogui.alert('Preenchimento realizado com sucesso ✅')

# %% [markdown]
# ### 📩Confecção dos emails

# %%
df = pd.read_excel("Plan_RNC.xlsx", dtype={'COD-ITEM': str}) #Atualizar planilha

for index, row in df.iterrows():
    if row["UNIDADE"] == "Hortolândia":
        sigla = "HORT"
    if row["UNIDADE"] == "Cuiabá":
        sigla = "CBA"



def desligar_num_lock():
    # Código virtual da tecla Num Lock no Windows
    VK_NUMLOCK = 0x90
    
    # Verifica o estado atual da tecla
    # O operador '& 1' pega o bit menos significativo, que indica se o "toggle" está ativo
    estado = ctypes.windll.user32.GetKeyState(VK_NUMLOCK)
    
    if estado & 1:
        print("O Num Lock está LIGADO. Desligando agora...")
        
        # Simula pressionar a tecla (Key Down)
        ctypes.windll.user32.keybd_event(VK_NUMLOCK, 0, 0, 0)
        # Pequena pausa para o sistema registrar (opcional, mas recomendado)
        time.sleep(0.05)
        # Simula soltar a tecla (Key Up) - O '2' representa KEYEVENTF_KEYUP
        ctypes.windll.user32.keybd_event(VK_NUMLOCK, 0, 2, 0)
        
        print("Num Lock foi desligado com sucesso.")
    else:
        print("O Num Lock já está DESLIGADO. Nenhuma ação necessária.")


# Executa a função
if __name__ == "__main__":
    desligar_num_lock()



pyautogui.click(1775,22) # Minimizar VSCode



pyautogui.sleep(1)
pyautogui.click(691,963)
pyautogui.sleep(1)


for index, row in df.iterrows():
    if row["CAUSA-RAIZ"] == 0:
        continue
    else:
            var_rnc = str(int(row['NUM-RNC']))
            pyautogui.hotkey('ctrl','home')
            pyautogui.sleep(0.7)

            pyautogui.press('down')
            pyautogui.press('down')
            pyautogui.press('down')
            pyautogui.press('down')
            pyautogui.press('down')
            pyautogui.press('down')

            pyautogui.sleep(0.5)
            pyautogui.press('right')

            pyautogui.sleep(0.7)
            var_nf = str(int(row['NUMERO-NF']))
            keyboard.write(str(int(row['NUMERO-NF'])))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            keyboard.write(str(row['NOME-PRODUTO']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            keyboard.write(str(row['LOTE']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            keyboard.write(str(row['NF-DATA-FABRICACAO']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            keyboard.write(str(row['NF-DATA-VALIDADE']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            var_qtd = str(int(row['QUANTIDADE']))
            keyboard.write(str(int(row['QUANTIDADE'])))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            keyboard.write(str(row['REAL-LOTE']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            keyboard.write(str(row['REAL-DATA-FABRICACAO']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            keyboard.write(str(row['REAL-DATA-VALIDADE']))
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            keyboard.write(str(int(row['QUANTIDADE'])))
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            var_uni = str(row['UNIDADE-MED'])
            keyboard.write(f'{var_qtd}{var_uni}')
            pyautogui.press('tab')
            pyautogui.sleep(0.7)

            resumo = str(row['RESUMO-RAPIDO'])
            keyboard.write(str(row['RESUMO-RAPIDO']))
            pyautogui.sleep(0.7)

            # Copiar Planilha para Email

            anexos = str(row['PASTA-ANEXOS'])

            pyautogui.hotkey('ctrl','home')
            pyautogui.sleep(1)

            pyautogui.hotkey('shift','space')
            pyautogui.sleep(0.7)

            with pyautogui.hold('shift'):
                pyautogui.press('down',7)

            pyautogui.sleep(0.5)
            pyautogui.hotkey('ctrl','c')     
            pyautogui.sleep(1)

            # Preparar Email

            webbrowser.open('https://outlook.office.com/mail/')
            pyautogui.sleep(12)

            pyautogui.click(106,232)
            pyautogui.sleep(3)

            keyboard.write('leandro.lima@nitro.com.br; ulisses.venancio@nitro.com.br; barbara.silva@nitro.com.br; tamissa.avanco@nitro.com.br; larissa.larangeira@nitro.com.br; flavio.faria@nitro.com.br; luciana.vicentin@nitro.com.br')
            pyautogui.sleep(3)
            pyautogui.press('tab')
            pyautogui.press('tab')
            

            if row["UNIDADE"] == "Hortolândia":
                pyautogui.sleep(0.5)
                keyboard.write('clayton.silva@mmcm.com.br; victor.aquino@mmcm.com.br; rodrigo.santos@mmcm.com.br; regina.allegretti@mmcm.com.br; ronaldo.borcari@nitro.com.br; agendamentonitro@mmcm.com.br')
                pyautogui.sleep(2.5)
            else:
                pyautogui.sleep(0.5)
                keyboard.write('clayton.silva@mmcm.com.br; victor.aquino@mmcm.com.br; rodrigo.santos@mmcm.com.br; regina.allegretti@mmcm.com.br; ronaldo.borcari@nitro.com.br; agendamentonitro@mmcm.com.br; emanuel.melo@mmcm.com.br; eduarda.silva@mmcm.com.br')
                pyautogui.sleep(2.5)

            pyautogui.press('tab')
            pyautogui.press('tab')
            pyautogui.sleep(1.5)

            causa = str(row['CAUSA-RAIZ'])

            #RNC 346 - NF 7900 DEVOLUÇÃO CBA / Caixas molhadas, deterioradas
            keyboard.write(f'RNC {var_rnc} - NF {var_nf} {sigla} / {causa}')
            pyautogui.press('tab')
            pyautogui.sleep(0.9)

            keyboard.write(f'''
            Prezados,
            Segue RNC {var_rnc} ✅ 
                           
            PSC.
            ''',0.03)

            keyboard.write('@lucian',0.03)
            pyautogui.sleep(0.9)
            pyautogui.press('tab',2)

            keyboard.write('@clayto',0.03)
            pyautogui.sleep(0.9)
            pyautogui.press('enter',3)

            pyautogui.hotkey('ctrl','v')
            pyautogui.sleep(1)

            pyautogui.press('ctrl')
            pyautogui.sleep(0.7)

            pyautogui.press('up')
            pyautogui.sleep(0.7)

            pyautogui.press('enter')
            pyautogui.sleep(1)

            pyautogui.click(982,259) 
            pyautogui.sleep(0.9)

            pyautogui.click(785,349) 
            pyautogui.sleep(1.5)

            pyautogui.click(573,66)
            pyautogui.sleep(1)
            keyboard.write('C:\\Users\\iesus.candido\\Desktop\\AUTO-RNC\\')
            keyboard.write(anexos)
            pyautogui.sleep(0.5)
            pyautogui.press('enter')
            pyautogui.sleep(0.7)

            pyautogui.press('tab',5)
            pyautogui.sleep(0.7)
            pyautogui.hotkey('ctrl','a')
            pyautogui.sleep(1)
            pyautogui.press('enter',3)
            
            
            pyautogui.sleep(15) # Tempo para subir anexos
            pyautogui.hotkey('ctrl','s')
            pyautogui.sleep(5)
            pyautogui.hotkey('ctrl','w')
            pyautogui.sleep(1)
            pyautogui.press('enter')
            pyautogui.sleep(1)

pyautogui.sleep(1)
pyautogui.click(305,962)
pyautogui.sleep(0.7)
pyautogui.hotkey('ctrl','w')

pyautogui.alert('Emails aguardando validação manual para envio ✅')
# Out:
# c:\Users\iesus.candido\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# O Num Lock já está DESLIGADO. Nenhuma ação necessária.
# 'OK'
